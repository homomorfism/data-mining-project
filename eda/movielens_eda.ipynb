# %%
import pandas as pd
import itertools as it

# %%
movielens = pd.read_csv("data/movie_lens/movie_lens_1m.csv")

# %%
genres = list(it.chain(*movielens.Genres.apply(lambda x: x.split("|"))))
genres = pd.Series(genres)
genres.value_counts().plot.barh()
# Out:
# <AxesSubplot:>
